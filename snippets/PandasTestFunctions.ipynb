# %% [markdown]
# https://pandas.pydata.org/pandas-docs/stable/getting_started/10min.html

# %%
import pandas as pd
import json

# %%
pd.DataFrame({'Y':[10,20,30,40],'Z':[1,2,3,4]})
# Out:
#     Y  Z
# 0  10  1
# 1  20  2
# 2  30  3
# 3  40  4

# %%
pd.DataFrame({'a':['sujoy','bijoy']}, index =['a','b'])
# Out:
#        a
# a  sujoy
# b  bijoy

# %%
tails=pd.read_csv(r"C:\Sujoy\Work\Docs\WSSS_2019-03-01T00_00_00.csv")
tails.shape
tails
##Neeed to work on this.. later
#arrivals=pd.read_json(r"C:\Users\Sujoy.Mukherjee\Python\arrivals.json")
#with open(r"C:\Users\Sujoy.Mukherjee\Python\arrivals.json") as f:
#    data = json.load(f)
#val1 = json.loads(json.dumps(arrivals))
#val2 = val1['tags'][0]['results'][0]['values']
#print pd.DataFrame(val2, columns=["time", "temperature", "quality"])
# Out:
#      AIRLINE FLIGHT#    EQUIP  TAIL  ORIG                 DEST  \
# SIA    208.0     NaN    9VSMF  YMML  WSSS  2019-02-28 08:25:00
# TGW     13.0    B789    9VOJD  YSSY  WSSS  2019-02-28 08:15:00
# JSA    584.0     NaN    9VJSR  VYYY  WSSS  2019-02-28 13:05:00
# SIA    949.0    A333    9VSTV  WADD  WSSS  2019-02-28 13:45:00
# QFA      1.0    A388    VHOQC  YSSY  WSSS  2019-02-28 06:00:00
# CAL   6871.0     NaN   B18720  RCTP  WSSS                  NaN
# MAS    609.0    B738    9MMLL  WMKK  WSSS  2019-02-28 15:30:00
# JSA    538.0     NaN    9VJSI  VTSP  WSSS  2019-02-28 14:55:00
# SIA    981.0    A333    9VSTZ  VTBS  WSSS  2019-02-28 14:10:00
# TGW    895.0     NaN    9VOFB  RCKH  WSSS  2019-02-28 12:40:00
# JSA    542.0     NaN    9VJSF  VVDN  WSSS  2019-02-28 13:50:00
# JSA    206.0     NaN    9VJSH  WIII  WSSS  2019-02-28 14:55:00
# JSA    766.0     NaN    9VJSA  RPLL  WSSS  2019-02-28 12:50:00
# ANA    801.0    B789   JA896A  RJAA  WSSS  2019-02-28 09:05:00
# ...

# %% [raw]
# #tails.iloc[2,5]
# #tails['FLIGHT#']=='208'
# #tails.describe()
# #tails.dtypes
# #tails.iloc[:, [1,2,3,4,7]].groupby(['FLIGHT#']).count()
# #tails.groupby('EQUIP').EQUIP.count()
# #tails.loc[:,'FLIGHT#':'ORIG'].groupby('FLIGHT#').count()
# tails.groupby(['EQUIP','FLIGHT#']).count()

# %%
tails.isna().sum()
# Out:
# AIRLINE                 1
# FLIGHT#               255
# EQUIP                   6
# TAIL                    0
# ORIG                    0
# DEST                  100
# SCHEDULED DEPATURE      0
# ACTUAL OFF GROUND     169
# DEP 06:00             148
# DEP 04:00             126
# DEP 02:00             113
# DEP 01:00               0
# STAR                    0
# ACTUAL ON APPROACH      0
# ACTUAL ON GROUND       11
# SCHEDULED ARRIVAL      62
# ARR FIRST             109
# ARR 06:00              87
# ARR 04:00              70
# ARR 02:00              65
# ARR 01:00              64
# ARR 00:30              63
# STAR.1                537
# dtype: int64

# %%
tails.columns
tails.describe()
tails.T
# Out:
#                                     SIA                  TGW  \
# AIRLINE                             208                   13
# FLIGHT#                             NaN                 B789
# EQUIP                             9VSMF                9VOJD
# TAIL                               YMML                 YSSY
# ORIG                               WSSS                 WSSS
# DEST                2019-02-28 08:25:00  2019-02-28 08:15:00
# SCHEDULED DEPATURE  2019-02-28 16:50:00  2019-02-28 16:37:00
# ACTUAL OFF GROUND                   NaN                  NaN
# DEP 06:00                           NaN                  NaN
# DEP 04:00                           NaN                  NaN
# DEP 02:00                           NaN                  NaN
# DEP 01:00                       REPOV1A              SURGA1A
# STAR                2019-02-28T23:44:25  2019-02-28T23:25:52
# ACTUAL ON APPROACH  2019-03-01T00:03:29  2019-03-01T00:06:09
# ...

# %%
tails.sort_index(axis=0,ascending=False)
# Out:
#      AIRLINE FLIGHT#    EQUIP  TAIL  ORIG                 DEST  \
# VJC    915.0    A321   VNA645  VVNB  WSSS  2019-03-01 02:35:00
# VJC    813.0    A320   VNA672  VVTS  WSSS  2019-03-01 05:55:00
# VJC    811.0    A320   VNA671  VVTS  WSSS  2019-03-01 02:00:00
# UZB    553.0    B764  UK67003  UTTT  WSSS  2019-02-28 18:35:00
# UPS    167.0    B763   N345UP  ZGSZ  WSSS                  NaN
# UPS     35.0    B744   N572UP  YSSY  WSSS                  NaN
# UBG    307.0     NaN    S2AJB  VGHS  WSSS  2019-02-28 16:30:00
# UBA      1.0    B738    XYALF  VYYY  WSSS  2019-03-01 00:45:00
# UBA      3.0     NaN    XYALB  VYYY  WSSS  2019-03-01 09:30:00
# UAL      1.0    B789   N27959  KSFO  WSSS  2019-02-28 06:40:00
# UAL     29.0    B789   N27958  KSFO  WSSS  2019-02-28 18:55:00
# UAE    405.0     NaN    A6EPB  YMML  WSSS  2019-03-01 07:45:00
# UAE    432.0     NaN    A6EGI  OMDB  WSSS  2019-02-28 17:15:00
# UAE    352.0    A388    A6EDL  OMDB  WSSS  2019-03-01 05:20:00
# ...

# %%
tails.sort_values(['AIRLINE','FLIGHT#'],ascending=[False,False])
#tails.axes
# Out:
#      AIRLINE FLIGHT#    EQUIP  TAIL  ORIG                 DEST  \
# CSZ   9185.0    B738    B1755  ZSCN  WSSS  2019-03-01 00:20:00
# CSZ   9023.0     NaN    B1756  ZGSZ  WSSS  2019-03-01 04:00:00
# CSZ   9021.0    B738    B1713  ZGSZ  WSSS  2019-03-01 01:55:00
# CBG   8967.0    A320    B8511  ZGNN  WSSS                  NaN
# CQH   8549.0     NaN    B1657  ZSPD  WSSS  2019-03-01 07:40:00
# CSN   8489.0    A319    B6209  ZGGG  WSSS  2019-02-28 15:05:00
# ANA   8411.0    B763   JA601F  ROAH  WSSS  2019-02-28 20:05:00
# KAL   8395.0     NaN   HL7603  RKSI  WSSS                  NaN
# SIA   8122.0     NaN    9VSRM  YSSY  WSSS                  NaN
# CSC   8093.0    A321    B8680  ZUUU  WSSS  2019-03-01 05:35:00
# SIA   7859.0     NaN    9VSFO  VHHH  WSSS  2019-03-01 09:20:00
# SIA   7855.0     NaN    9VSFO  ZSPD  WSSS                  NaN
# SIA   7291.0     NaN    9VSFN  NZAA  WSSS                  NaN
# APG   7236.0     NaN  RPC3227  RPVM  WSSS                  NaN
# ...

# %%
xl=pd.read_excel("C:\Sujoy\Work\Docs\LCC-List.xlsx")
xl.shape
# Out:
# (318, 9)

# %%
xl.head(30)
# Out:
#                               Unnamed: 0      Unnamed: 1  \
# 0       List of Low-Cost-Carriers (LCCs)             NaN
# 1                based on ICAO definiton             NaN
# 2                                    NaN             NaN
# 3   Global Air Transport Outlook to 2030             NaN
# 4                             ICAO DATA+             NaN
# 5                                    NaN             NaN
# 6                                    NaN             NaN
# 7                                    NaN             NaN
# 8                                 Region  Country of AOC
# 9                                 Africa    South Africa
# 10                                Africa           Egypt
# 11                                   NaN             NaN
# 12                                Africa         Morroco
# 13                                Africa           Egypt
# 14                                Africa           Kenya
# ...

# %%
xl.index
# Out:
# RangeIndex(start=0, stop=318, step=1)
